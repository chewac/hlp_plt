# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot ([1,2,3,4,5,6],[0.3,0.2,0.7,0.5,0.9,0.1])
plt.plot ([1,2,3,4,5,6],[0.2,0.7,0.5,0.9,0.1,None])
plt.plot ([1,2,3,4,5,6],[0.7,0.5,0.9,0.1,None,None])
